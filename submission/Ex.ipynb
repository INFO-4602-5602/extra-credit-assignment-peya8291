# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pylab as plt
# %matplotlib inline
import pylab as pl
from pandas import *

#read dataset
dfH= pd.read_csv("usp.csv")
dfH
#change the date type
dfH['Date Local']=pd.to_datetime(dfH['Date Local'])
#dfg= dfH.sort_values(by="Date", ascending=True)
print(dfH.head(10))

#plot the dataset line graph
ax=dfH.plot(x = "Date Local", y = ["NO2 Mean", "O3 Mean", "SO2 Mean", "CO Mean"],figsize=(20,10), grid=True,title="Pollutants Change")
ax.set_xlabel("Date", fontsize=16)
ax.set_ylabel("Value", fontsize=16)
plt.show()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
# 5           5           4           13      3002
# 6           6           4           13      3002
# 7           7           4           13      3002
# 8           8           4           13      3002
# 9           9           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# ...

# %%
#build a dataset for test
data = {'Participant': ['Zening', 'Zhixing', 'Yifan', 'Yiman', 'Tianlun'],
        'Value':   [5, 4, 3, 6, 3]
        }

df = pd.DataFrame(data)
print(df)

#plot line graph for test
ax=df.plot(x = 'Participant', y = 'Value',figsize=(15,5), grid=True,title="Test",style='.-')
ax.set_xlabel("Participant", fontsize=10)
ax.set_ylabel("Value", fontsize=16)
# Out:
#   Participant  Value
# 0      Zening      5
# 1     Zhixing      4
# 2       Yifan      3
# 3       Yiman      6
# 4     Tianlun      3
# Text(0,0.5,'Value')
